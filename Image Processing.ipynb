# %%
from PIL import image
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [1], in <module>
# ----> 1 from PIL import image
#       2 import numpy as np
#
# ImportError: cannot import name 'image' from 'PIL' (c:\users\archi\appdata\local\programs\python\python39\lib\site-packages\PIL\__init__.py)

# %%
# !pip install pillow

# %%
from PIL import Image
import numpy as np

# %%
pil=Image.open("thor.jpg")

# %%
array=np.array(pil)

# %%
array.shape
# Out:
# (246, 220, 3)

# %%
pil
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=220x246 at 0x14B79F81D00>

# %% [markdown]
# # NOW WE WILL CUT THE PIXELS OUT OF THE ABOVE IMAGE

# %%
import matplotlib.pyplot as plt

# %%
cut=array[:20,:20]

# %%
plt.imshow(cut)

# %%
arr=array[:,:,0]  # (0,1,2 => red, green, blue)

# %%
arr
# Out:
# array([[ 67,  67,  68, ...,  79,  77,  75],
#        [ 66,  67,  67, ...,  81,  79,  78],
#        [ 66,  66,  67, ...,  82,  81,  80],
#        ...,
#        [139, 144, 138, ...,  54,  52,  51],
#        [129, 137, 119, ...,  55,  54,  53],
#        [108, 124, 107, ...,  55,  54,  53]], dtype=uint8)

# %%
plt.imshow(arr)

# %%
arr1=array.copy()

# %%
arr1[:,:,[0,1]]=0

# %%
plt.imshow(arr1)

# %% [markdown]
# # converting the thor image in black image

# %%
gray=array.mean(axis=2)

# %%
gray.shape
# Out:
# (246, 220)

# %%
plt.imshow(gray,cmap="gray")

# %%
gray
# Out:
# array([[ 65.        ,  65.        ,  66.        , ...,  78.33333333,
#          76.33333333,  74.33333333],
#        [ 64.        ,  65.        ,  65.        , ...,  80.33333333,
#          78.33333333,  77.33333333],
#        [ 64.        ,  64.        ,  65.        , ...,  81.33333333,
#          80.33333333,  79.33333333],
#        ...,
#        [133.        , 137.33333333, 129.33333333, ...,  25.        ,
#          24.33333333,  23.33333333],
#        [123.33333333, 131.        , 111.        , ...,  26.        ,
#          25.        ,  24.        ],
#        [102.33333333, 118.        ,  99.33333333, ...,  26.        ,
#          25.        ,  24.        ]])

# %%
gray.shape
# Out:
# (246, 220)
