# %%
import tensorflow

# %%
from tensorflow.keras.datasets import mnist

# %%
[x_train , y_train],[x_test,y_test] = mnist.load_data()

# %%
from sklearn.datasets import make_blobs

# %%
x,y=make_blobs(n_samples=10000,centers=2,random_state=42)  # this y is of no use

# %%
import seaborn as sns

# %%
sns.scatterplot(x[:,0],x[:,1],hue=y)
# Out:
# c:\users\archi\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
y_mod = y.reshape(-1,1)

# %%
y_mod.shape
# Out:
# (10000, 1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model=Sequential()

d1=Dense(units=1,activation="sigmoid",input_shape=(2,))

model.add(d1)

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1)                 3
#
# =================================================================
# Total params: 3
# Trainable params: 3
# Non-trainable params: 0
# _________________________________________________________________

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(
...     x, y_mod, test_size=0.33, random_state=42)

# %%
model.compile(optimizer="adam",loss="binary_crossentropy",metrics=["accuracy"])

# %%
model.fit(x_train,y_train,epochs=10,batch_size=1000)
# Out:
# Epoch 1/10
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6370 - accuracy: 0.5585
# Epoch 2/10
# 7/7 [==============================] - 0s 1ms/step - loss: 0.6078 - accuracy: 0.5730
# Epoch 3/10
# 7/7 [==============================] - 0s 1ms/step - loss: 0.5797 - accuracy: 0.5919
# Epoch 4/10
# 7/7 [==============================] - 0s 1ms/step - loss: 0.5526 - accuracy: 0.6088
# Epoch 5/10
# 7/7 [==============================] - 0s 1ms/step - loss: 0.5266 - accuracy: 0.6285
# Epoch 6/10
# 7/7 [==============================] - 0s 1ms/step - loss: 0.5017 - accuracy: 0.6476
# Epoch 7/10
# 7/7 [==============================] - 0s 1ms/step - loss: 0.4778 - accuracy: 0.6667
# Epoch 8/10
# 7/7 [==============================] - 0s 1ms/step - loss: 0.4553 - accuracy: 0.6921
# Epoch 9/10
# 7/7 [==============================] - 0s 1ms/step - loss: 0.4338 - accuracy: 0.7103
# Epoch 10/10
# 7/7 [==============================] - 0s 1ms/step - loss: 0.4133 - accuracy: 0.7306

# %%
model.evaluate(x_test,y_test)
# Out:
# 104/104 [==============================] - 0s 1ms/step - loss: 0.3882 - accuracy: 0.7609
# [0.38823914527893066, 0.7609090805053711]
